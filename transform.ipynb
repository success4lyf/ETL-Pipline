# %%
import pandas as pd
df = pd.read_csv("data/chesterfield_25-08-2021_09-00-00.csv")
df.head()
# Out:
#   Timestamp of Purchase    Store Name      Customer Name  \
# 0      25/08/2021 09:02  Chesterfield        Scott Owens
# 1      25/08/2021 09:04  Chesterfield  Francis Strayhorn
# 2      25/08/2021 09:06  Chesterfield       Rodney Drake
# 3      25/08/2021 09:08  Chesterfield    Michael Sparrow
# 4      25/08/2021 09:10  Chesterfield    Thomas Register
#
#                    Basket Items (Name, Size & Price)  Total Price Cash/Card  \
# 0  Large Flavoured iced latte - Caramel - 3.25, R...        17.30      CARD
# 1      Large Flat white - 2.45, Regular Latte - 2.15         4.60      CARD
# 2  Regular Flavoured latte - Hazelnut - 2.55, Lar...         5.00      CARD
# 3           Regular Latte - 2.15, Large Latte - 2.45         4.60      CASH
# 4  Large Flavoured iced latte - Caramel - 3.25, R...        12.95      CASH
#
#    Card Number (Empty if Cash)
# 0                 6.844802e+15
# 1                 9.557104e+15
# 2                 2.978328e+15
# 3                          NaN
# ...

# %%
to_drop = ["Customer Name", "Card Number (Empty if Cash)"]
df.drop(columns=to_drop, inplace=True)
df
# Out:
#     Timestamp of Purchase    Store Name  \
# 0        25/08/2021 09:02  Chesterfield
# 1        25/08/2021 09:04  Chesterfield
# 2        25/08/2021 09:06  Chesterfield
# 3        25/08/2021 09:08  Chesterfield
# 4        25/08/2021 09:10  Chesterfield
# ..                    ...           ...
# 262      25/08/2021 16:45  Chesterfield
# 263      25/08/2021 16:49  Chesterfield
# 264      25/08/2021 16:52  Chesterfield
# 265      25/08/2021 16:56  Chesterfield
# 266      25/08/2021 16:59  Chesterfield
#
#                      Basket Items (Name, Size & Price)  Total Price Cash/Card
# 0    Large Flavoured iced latte - Caramel - 3.25, R...        17.30      CARD
# 1        Large Flat white - 2.45, Regular Latte - 2.15         4.60      CARD
# 2    Regular Flavoured latte - Hazelnut - 2.55, Lar...         5.00      CARD
# 3             Regular Latte - 2.15, Large Latte - 2.45         4.60      CASH
# 4    Large Flavoured iced latte - Caramel - 3.25, R...        12.95      CASH
# ...

# %%
# converting time of purchase to yyyy-mm-dd h:m:s
df['Timestamp of Purchase'] = pd.to_datetime(df['Timestamp of Purchase'])
df.head(10)
# Out:
#   Timestamp of Purchase    Store Name  \
# 0   2021-08-25 09:02:00  Chesterfield
# 1   2021-08-25 09:04:00  Chesterfield
# 2   2021-08-25 09:06:00  Chesterfield
# 3   2021-08-25 09:08:00  Chesterfield
# 4   2021-08-25 09:10:00  Chesterfield
# 5   2021-08-25 09:12:00  Chesterfield
# 6   2021-08-25 09:14:00  Chesterfield
# 7   2021-08-25 09:17:00  Chesterfield
# 8   2021-08-25 09:19:00  Chesterfield
# 9   2021-08-25 09:21:00  Chesterfield
#
#                    Basket Items (Name, Size & Price)  Total Price Cash/Card
# 0  Large Flavoured iced latte - Caramel - 3.25, R...        17.30      CARD
# 1      Large Flat white - 2.45, Regular Latte - 2.15         4.60      CARD
# 2  Regular Flavoured latte - Hazelnut - 2.55, Lar...         5.00      CARD
# 3           Regular Latte - 2.15, Large Latte - 2.45         4.60      CASH
# 4  Large Flavoured iced latte - Caramel - 3.25, R...        12.95      CASH
# 5  Large Flavoured latte - Hazelnut - 2.85, Regul...        17.40      CARD
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Timestamp of Purchase              267 non-null    datetime64[ns]
#  1   Store Name                         267 non-null    object
#  2   Basket Items (Name, Size & Price)  267 non-null    object
#  3   Total Price                        267 non-null    float64
#  4   Cash/Card                          267 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 10.6+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
new_df = df.to_csv("data/transformed_data.csv", index=False)
new_df
